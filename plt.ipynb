# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
width_td3 = np.load('./results/TD3_Hopper-v3_0_width_reset1000-100.npy')
td3 = np.load('./results/TD3_Hopper-v3_0_.npy')
width_td3_noreset = np.load('./results/TD3_Hopper-v3_0_width_without_reset.npy')
width_td3_noreset_clip5 = np.load('./results/TD3_Hopper-v3_0_width_without_reset_clip5.npy')
width_reset_everytime = np.load('./results/TD3_Hopper-v3_0_width_reset_everytime_scale{5e-05}.npy')
plt.plot(width_td3, label='td3+width', color='red')
plt.plot(td3[:], label='td3')
# plt.plot(width_td3_noreset, label='td3+width without reset')
plt.plot(width_reset_everytime, label='reset everytime scale 5e-5')
plt.plot(width_td3_noreset_clip5, label='td3+width without reset + clip 5')
plt.legend()

# %%
width_td3 = np.load('./results/TD3_Hopper-v3_0_nonoise_without_reset_scale0.005.npy')
td3 = np.load('./results/TD3_Hopper-v3_0_.npy')
# width_td3_noreset = np.load('./results/TD3_Hopper-v3_0_width_without_reset.npy')
# width_td3_noreset_clip5 = np.load('./results/TD3_Hopper-v3_0_width_without_reset_clip5.npy')
# width_reset_everytime = np.load('./results/TD3_Hopper-v3_0_width_reset_everytime_scale{5e-05}.npy')
plt.plot(width_td3, label='td3+width', color='red')
plt.plot(td3[:], label='td3')
# plt.plot(width_td3_noreset, label='td3+width without reset')
# plt.plot(width_reset_everytime, label='reset everytime scale 5e-5')
# plt.plot(width_td3_noreset_clip5, label='td3+width without reset + clip 5')
plt.legend()

# %%
width_list = np.load('./width_log/TD3_Hopper-v3_0_width_without_reset_width_log.npy')
plt.plot(width_list)

# %%
width_list = np.load('./width_log/TD3_Hopper-v3_0_width_reset1000-100_width_log.npy')
plt.plot(width_list)

# %%
width_list = np.load('./width_log/TD3_Hopper-v3_0_width_without_reset_clip5_width_log.npy')
plt.plot(width_list)

# %%
width_list = np.load('./width_log/TD3_Hopper-v3_0_width_reset_everytime_width_log.npy')
plt.plot(width_list)
